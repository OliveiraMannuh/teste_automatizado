# %%
# !pip install pyautogui
# !pip install selenium
# !pip install webdriver_manager

import subprocess
import pyautogui 
import time
import datetime
# -*- coding: utf-8 -*-
coding='UTF-8'

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())

pyautogui.PAUSE = 1  # Pausa de 1 segundo entre as ações do PyAutoGUI

# Configurar o driver do Selenium (neste exemplo, usando o ChromeDriver)
driver = webdriver.Chrome(service=servico)

#maximizar navegador
driver.maximize_window()

# Abrir o navegador
driver.get('https://www.selenium.dev/')
# Out:
# Requirement already satisfied: pyautogui in /home/manuela_oliveira/.local/lib/python3.8/site-packages (0.9.54)
# Requirement already satisfied: pytweening>=1.0.4 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: mouseinfo in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: python3-Xlib; platform_system == "Linux" and python_version >= "3.0" in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from pyautogui) (0.15)
# Requirement already satisfied: pygetwindow>=0.0.5 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: pyscreeze>=0.1.21 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from pyautogui) (1.0.1)
# Requirement already satisfied: pymsgbox in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pyperclip in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from mouseinfo->pyautogui) (1.9.0)
# Requirement already satisfied: pyrect in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: Pillow>=9.2.0; python_version == "3.8" in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from pyscreeze>=0.1.21->pyautogui) (10.4.0)
# Requirement already satisfied: selenium in /home/manuela_oliveira/.local/lib/python3.8/site-packages (4.27.1)
# Requirement already satisfied: typing_extensions~=4.9 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from selenium) (4.13.2)
# Requirement already satisfied: trio-websocket~=0.9 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from selenium) (0.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from selenium) (2.2.3)
# Requirement already satisfied: trio~=0.17 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from selenium) (0.27.0)
# Requirement already satisfied: certifi>=2021.10.8 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from selenium) (2025.10.5)
# Requirement already satisfied: exceptiongroup; python_version < "3.11" in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from trio-websocket~=0.9->selenium) (1.2.2)
# Requirement already satisfied: wsproto>=0.14 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: outcome>=1.2.0 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from trio-websocket~=0.9->selenium) (1.3.0.post0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6; extra == "socks" in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: sniffio>=1.3.0 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: attrs>=23.2.0 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from trio~=0.17->selenium) (25.3.0)
# Requirement already satisfied: idna in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from trio~=0.17->selenium) (3.11)
# Requirement already satisfied: sortedcontainers in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.16.0)
# Requirement already satisfied: webdriver_manager in /home/manuela_oliveira/.local/lib/python3.8/site-packages (4.0.2)
# Requirement already satisfied: requests in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from webdriver_manager) (2.32.4)
# Requirement already satisfied: python-dotenv in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from webdriver_manager) (1.0.1)
# Requirement already satisfied: packaging in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from webdriver_manager) (25.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from requests->webdriver_manager) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from requests->webdriver_manager) (2025.10.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from requests->webdriver_manager) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/manuela_oliveira/.local/lib/python3.8/site-packages (from requests->webdriver_manager) (2.2.3)
