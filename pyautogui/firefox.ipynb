# %%
import subprocess
import pyautogui 
import time
import datetime
# -*- coding: utf-8 -*-
coding='UTF-8'

pyautogui.PAUSE = 0.5
pyautogui.press('win')
pyautogui.write('firefox')
pyautogui.press('enter')
time.sleep(5)
pyautogui.hotkey('ctrl','l')
pyautogui.write('https://pyautogui.readthedocs.io/en/latest')
pyautogui.press('enter')
